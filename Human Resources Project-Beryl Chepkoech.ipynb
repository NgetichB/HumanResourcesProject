# %%
import pandas as pd

# %%
#Human Resource Dataset
#Loading the datasetinto Pandas dataframe and displaying the first five rows

data = pd.read_csv("C:/Users/Administrator/Documents/DATA ANALYTICS-SCIENCE/MACHINE LEARNING/HRDataset_v14.csv")
data.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
#Check the shape of the dataset- rows(311) and columns(36)
df = data
print(df.shape)
# Out:
# (311, 36)

# %%
#Displaying the column names and their data types
print(df.dtypes)
# Out:
# Employee_Name                  object
# EmpID                           int64
# MarriedID                       int64
# MaritalStatusID                 int64
# GenderID                        int64
# EmpStatusID                     int64
# DeptID                          int64
# PerfScoreID                     int64
# FromDiversityJobFairID          int64
# Salary                          int64
# Termd                           int64
# PositionID                      int64
# Position                       object
# State                          object
# Zip                             int64
# DOB                            object
# Sex                            object
# MaritalDesc                    object
# CitizenDesc                    object
# HispanicLatino                 object
# RaceDesc                       object
# DateofHire                     object
# DateofTermination              object
# TermReason                     object
# EmploymentStatus               object
# ...

# %%
#4.Finding the number of unique values in each column
print(df.nunique())
# Out:
# Employee_Name                 311
# EmpID                         311
# MarriedID                       2
# MaritalStatusID                 5
# GenderID                        2
# EmpStatusID                     5
# DeptID                          6
# PerfScoreID                     4
# FromDiversityJobFairID          2
# Salary                        308
# Termd                           2
# PositionID                     30
# Position                       32
# State                          28
# Zip                           158
# DOB                           307
# Sex                             2
# MaritalDesc                     5
# CitizenDesc                     3
# HispanicLatino                  4
# RaceDesc                        6
# DateofHire                    101
# DateofTermination              96
# TermReason                     18
# EmploymentStatus                3
# Department                      6
# ManagerName                    21
# ...

# %%
#5.Identifying missing values in the dataset and list columns with nulls
print(df.isnull().sum())
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ...

# %%
#6.Describe the numerical columns in the dataset-mean, median,std..
print(df.describe())
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# std      1.083487     0.587072                0.291248   25156.636930
# ...

# %%
#7.Find the distribution of employees salaries
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,6))
sns.histplot(df['Salary'], bins=30, kde=True)
plt.title('Distribution of Employee Salaries')
plt.xlabel('Salary')
# Out:
# Text(0.5, 0, 'Salary')

# %%
# The average age of employees at the company (Since there is no 'AGE' column, we calculate it using the Date of Birth)
from datetime import datetime

df['DOB'] = pd.to_datetime(df['DOB'])

# Calculate age
today = pd.Timestamp('today')
df['Age'] = (today - df['DOB']).dt.days // 365

average_age = df['Age'].mean()
print(f"The average age of employees is: {average_age:.2f} years")
# Out:
# The average age of employees is: 16.86 years
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_26848\3404201679.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['DOB'] = pd.to_datetime(df['DOB'])

# %%
#9 Number of employees still employed vs the terminated
employment_status_counts = df['EmploymentStatus'].value_counts()
print(employment_status_counts)
# Out:
# EmploymentStatus
# Active                    207
# Voluntarily Terminated     88
# Terminated for Cause       16
# Name: count, dtype: int64

# %%
#Department with the most employees
department_counts = df['Department'].value_counts()
most_employees_department = department_counts.idxmax()  
print(f"The department with the most employees is: {most_employees_department} with {department_counts.max()} employees.")
# Out:
# The department with the most employees is: Production        with 209 employees.

# %%
#Business Analysis
#11.Average salary per department
average_salary_per_department = df.groupby('Department')['Salary'].mean()
print(average_salary_per_department)
# Out:
# Department
# Admin Offices            71791.888889
# Executive Office        250000.000000
# IT/IS                    97064.640000
# Production               59953.545455
# Sales                    69061.258065
# Software Engineering     94989.454545
# Name: Salary, dtype: float64

# %%
#12.The distribition of employment status (Active, Voluntary,Terminated)
employment_status_distribution = df['EmploymentStatus'].value_counts(normalize=True) * 100
print(employment_status_distribution)
# Out:
# EmploymentStatus
# Active                    66.559486
# Voluntarily Terminated    28.295820
# Terminated for Cause       5.144695
# Name: proportion, dtype: float64

# %%
#13.Compare Salary levels between Male and Female employees( We use column 'sex' in place of 'Gender')
Salary_Comparison = df.groupby("Sex")["Salary"].mean()
print(Salary_Comparison)
# Out:
# Sex
# F     67786.727273
# M     70629.400000
# Name: Salary, dtype: float64

# %%
#14.Recruitment Source that brings the most employees
recruitment_source_counts = df['RecruitmentSource'].value_counts()
most_common_source = recruitment_source_counts.idxmax()
print(f"The recruitment source that brings the most employees is: {most_common_source} with {recruitment_source_counts.max()} employees.")
# Out:
# The recruitment source that brings the most employees is: Indeed with 87 employees.

# %%
#15.Percentage of employees that attended a Diversity Job Fair
job_fair_percentage = (df['RecruitmentSource'].value_counts(normalize=True) * 100).get('Diversity Job Fair', 0)
print(f"Percentage of employees that attended Diversity Job Fair: {job_fair_percentage:.2f}%")
# Out:
# Percentage of employees that attended Diversity Job Fair: 9.32%

# %%
#16. Compare the engagement survey scores across different departments
engagement_scores_by_department = df.groupby('Department')['EngagementSurvey'].mean()
print(engagement_scores_by_department)
# Out:
# Department
# Admin Offices           4.393333
# Executive Office        4.830000
# IT/IS                   4.154000
# Production              4.129569
# Sales                   3.818710
# Software Engineering    4.061818
# Name: EngagementSurvey, dtype: float64

# %%
# Race with the highest average salary
average_salary_race = df.groupby('RaceDesc')['Salary'].mean()
print(average_salary_race)
# Out:
# RaceDesc
# American Indian or Alaska Native    65806.000000
# Asian                               68521.206897
# Black or African American           74431.025000
# Hispanic                            83667.000000
# Two or more races                   59998.181818
# White                               67287.545455
# Name: Salary, dtype: float64

# %%
#18.Relationship btwn no. of projects- Count of special projects and salary
projects_salary_correlation = df[['SpecialProjectsCount', 'Salary']].corr().iloc[0,1]
print(f"Correlation between number of special projects and salary: {projects_salary_correlation:.2f}")
# Out:
# Correlation between number of special projects and salary: 0.51

# %%
#19.Do married employees earn more on average than single employees?No, on average, the single employees earn more than married employees.
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
sns
average_salary_by_marital_status = df.groupby('MaritalDesc')['Salary'].mean()
print(average_salary_by_marital_status)
# Out:
# MaritalDesc
# Divorced     64427.333333
# Married      69827.717742
# Separated    62934.333333
# Single       70052.576642
# Widowed      65195.125000
# Name: Salary, dtype: float64

# %%
#20.Managers with the largest teams
managers_team_sizes = df['ManagerName'].value_counts()
largest_team_manager = managers_team_sizes.idxmax()
print(f"The manager with the largest team is: {largest_team_manager} with {managers_team_sizes.max()} employees.")
# Out:
# The manager with the largest team is: Michael Albert with 22 employees.

# %%
#Data Visualization
#21.Plot the salary distributions using histograms
import matplotlib.pyplot as plt
import seaborn as sns 
plt.figure(figsize=(10,6))
sns.histplot(df['Salary'], bins=30, kde=True)
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %%
#22.Count of employees by department using bar chart
sns.barplot(x=department_counts.index, y=department_counts.values)
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, 'Production       '),
#   Text(1, 0, 'IT/IS'),
#   Text(2, 0, 'Sales'),
#   Text(3, 0, 'Software Engineering'),
#   Text(4, 0, 'Admin Offices'),
#   Text(5, 0, 'Executive Office')])

# %%
#23.Comparing the average satisfaction score by department
average_satisfaction_score_by_department = df.groupby('Department')['EmpSatisfaction'].mean()
print(average_satisfaction_score_by_department)
sns.barplot(x=average_satisfaction_score_by_department.index, y=average_satisfaction_score_by_department.values)
plt.xticks(rotation=45)
# Out:
# Department
# Admin Offices           3.555556
# Executive Office        3.000000
# IT/IS                   3.960000
# Production              3.861244
# Sales                   4.032258
# Software Engineering    4.090909
# Name: EmpSatisfaction, dtype: float64
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, 'Admin Offices'),
#   Text(1, 0, 'Executive Office'),
#   Text(2, 0, 'IT/IS'),
#   Text(3, 0, 'Production       '),
#   Text(4, 0, 'Sales'),
#   Text(5, 0, 'Software Engineering')])

# %%
#24.Visualizing employees termination over time
df['Termd'] = pd.to_datetime(df['Termd'], errors='coerce')
df['TermYear'] = df['Termd'].dt.year
termination_counts_by_year = df['TermYear'].value_counts().sort_index()
plt.figure(figsize=(10,6))
plt.plot(termination_counts_by_year.index, termination_counts_by_year.values, marker='o')
plt.title('Employee Terminations Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Terminations')
sns.lineplot(x=termination_counts_by_year.index, y=termination_counts_by_year.values, marker='o')
plt.xticks(rotation=45)
# Out:
# (array([1850., 1875., 1900., 1925., 1950., 1975., 2000., 2025., 2050.,
#         2075., 2100.]),
#  [Text(1850.0, 0, '1850'),
#   Text(1875.0, 0, '1875'),
#   Text(1900.0, 0, '1900'),
#   Text(1925.0, 0, '1925'),
#   Text(1950.0, 0, '1950'),
#   Text(1975.0, 0, '1975'),
#   Text(2000.0, 0, '2000'),
#   Text(2025.0, 0, '2025'),
#   Text(2050.0, 0, '2050'),
#   Text(2075.0, 0, '2075'),
#   Text(2100.0, 0, '2100')])

# %%
# 25.Use a boxplot to plot the salary distribution by gender (Sex)
sns.boxplot(x='Sex', y='Salary', data=df)
plt.title('Salary Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Salary')
plt.show()

# %%
#26.Visualize performance scores vs salary using Stripplot
sns.stripplot(x='PerfScoreID', y='Salary', data=df, jitter=True)
plt.title('Performance Scores vs Salary')
performance_scores = df['PerfScoreID'].value_counts()
plt.xlabel('Performance Score')
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
#27.Heatmap of correlations between numeric variables
import seaborn as sns
numeric_correlation = df.select_dtypes(include=['number']).corr()
plt.figure(figsize=(12,8))
sns.heatmap(numeric_correlation, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Heatmap of Numeric Variables')
plt.show()
print(numeric_correlation)
# Out:
#                            EmpID  MarriedID  MaritalStatusID  GenderID  \
# EmpID                   1.000000   0.048058        -0.043851  0.035914
# MarriedID               0.048058   1.000000         0.164044 -0.024199
# MaritalStatusID        -0.043851   0.164044         1.000000 -0.030236
# GenderID                0.035914  -0.024199        -0.030236  1.000000
# EmpStatusID             0.073750   0.085619         0.114630 -0.032440
# DeptID                  0.107406  -0.119932         0.012768 -0.038838
# PerfScoreID            -0.691348  -0.058362         0.044693 -0.054915
# FromDiversityJobFairID  0.046805  -0.012708         0.041117  0.031493
# Salary                 -0.115319   0.026165        -0.070291  0.056097
# PositionID             -0.036488  -0.027334         0.021923 -0.081612
# Zip                     0.026858  -0.041147         0.010620  0.048539
# ManagerID               0.090236  -0.094002         0.023065 -0.043218
# ...

# %%
#28.Plotting engagement survey scores vs satisfaction score- Scatterplot
sns.scatterplot(x='EngagementSurvey', y='EmpSatisfaction', data=df)
plt.title('Engagement Survey Scores vs Satisfaction Scores')
plt.xlabel('Engagement Survey Score')
plt.ylabel('Employee Satisfaction Score')
plt.show()

# %%
#29.Plot a stacked bar chart of employees status across departments
import pandas as pd
import matplotlib.pyplot as plt 
status_department_counts = pd.crosstab(df['Department'], df['EmploymentStatus'])
status_department_counts.plot(kind='bar', stacked=True, figsize=(12,8))
plt.title('Employee Status Across Departments')
plt.xlabel('Department')
plt.ylabel('Number of Employees')
plt.show()

# %%
#30.Plot absenteeism distribution among employees using histogram-histplot
sns.histplot(df['Absences'], bins=30, kde=True)
plt.title('Distribution of Employee Absenteeism')
plt.xlabel('Number of Absences')
plt.show()

# %%
#PCA Dimensionality Reduction
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
#31.Standardize numeric features before applying PCA
numeric_cols = df.select_dtypes(include=['number']).columns
scaler = StandardScaler()
X = df.select_dtypes(include=['number']).dropna()
X_scaled = scaler.fit_transform(X)

# %%
#32.Perform PCA on the dataset and explain the first two components- scikit-learn PCA
scaled_data = scaler.fit_transform(df[numeric_cols].dropna())
pca = PCA(n_components=2)
pca_components = pca.fit_transform(scaled_data)
pca_df = pd.DataFrame(
    data=pca_components, 
    columns=["PC1", "PC2"]
)
print(pca_df.head())
# Out:
#         PC1       PC2
# 0  1.384489 -1.879708
# 1  2.274602  1.808130
# 2 -1.295208 -0.257118
# 3  0.709391 -1.166092
# 4 -0.364427 -2.889233

# %%
#33.Plot the explained variance ratio of the first two principal components
print(f"Explained variance ratio of the first two principal components: {pca.explained_variance_ratio_}")
# Out:
# Explained variance ratio of the first two principal components: [0.17673935 0.14384783]

# %%
#34.Reduce the dataset to two dimensions with PCA and plot employees- seaborn scatterplot
sns.scatterplot(x=pca_df['PC1'], y=pca_df['PC2'])
plt.title('PCA of Employee Data')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %%
#Which Variables contribute most to the first principal component
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import seaborn as sns
# Create a DataFrame of loadings
loadings = pd.DataFrame(
    pca.components_.T,  # transpose so variables are rows
    columns=[f"PC{i+1}" for i in range(pca.n_components_)],
    index=X.columns
)
print("Loadings for PC1:")
print(loadings["PC1"].sort_values(ascending=False))
# Out:
# Loadings for PC1:
# PerfScoreID               0.424281
# EngagementSurvey          0.366231
# SpecialProjectsCount      0.292574
# Salary                    0.269773
# EmpSatisfaction           0.158477
# MaritalStatusID           0.012729
# FromDiversityJobFairID    0.001723
# TermYear                 -0.000000
# GenderID                 -0.007119
# Age                      -0.007297
# Absences                 -0.008023
# MarriedID                -0.012147
# PositionID               -0.015250
# EmpStatusID              -0.106683
# Zip                      -0.108970
# ManagerID                -0.253515
# DeptID                   -0.317383
# EmpID                    -0.389649
# DaysLateLast30           -0.401959
# Name: PC1, dtype: float64

# %%
#36.Apply PCA to engagemnt + satisfaction +absences, condense into 1 dimension
sns.scatterplot(x=pca_df['PC1'], y=pca_df['PC2'])
plt.title('PCA of Employee Data')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %%
#38.Comparison of clustering before and after PCA using k means on numeric data-scikit-learn KMeans(BEFORE PCA)
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X_scaled)
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=kmeans.labels_, cmap='viridis')
plt.title('K-Means Clustering Before PCA')
# Out:
# Text(0.5, 1.0, 'K-Means Clustering Before PCA')

# %%
#AFTER PCA
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X_scaled)
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=kmeans.labels_, cmap='viridis')
plt.title('K-Means Clustering After PCA')
# Out:
# Text(0.5, 1.0, 'K-Means Clustering After PCA')

# %%
#39.Plot loadings of salary, abscences, engagement on the first two PCAs-PCA Biplot
biplot_data = loadings.loc[['Salary', 'Absences', 'EngagementSurvey'], ['PC1', 'PC2']]
plt.figure(figsize=(10, 8))
# Provide arrays of zeros for the starting points
plt.quiver(
    [0]*len(biplot_data), [0]*len(biplot_data),
    biplot_data['PC1'], biplot_data['PC2'],
    angles='xy', scale_units='xy', scale=1, color='r'
)
for i, txt in enumerate(biplot_data.index):
    plt.text(biplot_data['PC1'][i], biplot_data['PC2'][i], txt)
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_26848\2355360027.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(biplot_data['PC1'][i], biplot_data['PC2'][i], txt)

# %%
#Discuss when PCA is appropriate in HR analytics--analytics Vidhya-use cases

#PCA is an unsupervised algorithm that performs dimensionality reduction by transforming a dataset with many variables into a smaller set with fresh variables called principal components
#PCA is useful in HR Analytics whenever there is high dimensional HR data with many correlated variables, hence the data is reduced to afew uncorrelated components. 
#PCA in HR is useful in the following ways;
#1.Correlated variables-PCA transforms variables such as experience years, job level and salary band into independent components to avoid multicollinearity. 
#2.Dimensionality Reduction-HR datasets with numerous features like scores, engagements, training hours, job satisfation and performance; PCA cancels or reduces noise while maintaining the core data/information
#3.Data Visualization and Clustering-PCA allows you to plot data into 2d/3d plots hence makes it easier to detect clusters and identify patterns
#4.PCA helps reduce redundancy and speeds up computation in data Processing-
#The use cases in HR analytics are: Performance evaluation, employee attrition and engagement surveys, compensation benchmarking and recruiment analytics
